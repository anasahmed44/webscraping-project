# %%
import requests
import math
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Function to return number of pages
def num_of_pages(jop_title):
  link = 'https://wuzzuf.net/search/jobs/?q=' + jop_title.replace(' ', '+') + '&a=hpb'
  response = requests.get(link) 
  soup = BeautifulSoup(response.content, 'html')
  search_tag = soup.find('span', {'class': 'css-xkh9ud'})
  num_pages = math.ceil(int(search_tag.strong.text) / 15)
  return num_pages

# %%
# function for scraping
def scrape_pages(jop_title):
  number_of_pages = num_of_pages(jop_title)
  all_titles, all_links, all_locations, type_of_job= [], [], [], []
  for page in range(number_of_pages):
    link = 'https://wuzzuf.net/search/jobs/?a=hpb&q=' + jop_title.replace(' ', '%20') + '&start=' + str(page)
    response = requests.get(link)
    soup = BeautifulSoup(response.content, 'html')
    titles_links = soup.find_all('h2', {'class': 'css-m604qf'})
    titles = [tit.text for tit in titles_links]
    all_titles += titles
    links = ['https://wuzzuf.net/' + link.a['href'] for link in titles_links]
    all_links += links
    job_type = soup.find_all('div', {'class': 'css-1lh32fc'})
    job_types = [jop.text for jop in job_type]
    type_of_job += job_types
    company_location = soup.find_all('span', {'class': 'css-5wys0k'})
    locations = [location.text for location in company_location]
    all_locations += locations
  job = {}
  job['job_title'] = all_titles
  job['job_link'] = all_links
  job['job_loaction'] = all_locations
  job['job_type'] = type_of_job
  df = pd.DataFrame(job)
  return df 


scrape_pages('machine learning')
# Out:
#                                             job_title  \
# 0                    Senior Machine Learning Engineer
# 1                    Senior Machine Learning Engineer
# 2                           Machine Learning Engineer
# 3                           Senior Research Scientist
# 4                                     Product Manager
# 5                        Data Scientist "Senior/Lead"
# 6                     Senior Computer Vision Engineer
# 7                 AI Technical Lead (Computer Vision)
# 8                               Senior Data Scientist
# 9                               Senior Java Developer
# 10                                     Data Scientist
# 11                                Senior Risk Analyst
# 12                              Python Technical Lead
# 13                             Senior Cost Accountant
# 14  Industrial Controlling & Reporting Internship ...
# 15                                     Data Scientist
# 16                    Senior Data Management Engineer
# 17                           Data Management Engineer
# 18              Production Technology Lead Specialist
# 19              Data Science Software Engineer Intern
# 20                   Senior Python / Django Developer
# 21                            Junior Python Developer
# 22                Receptionist & Facility Coordinator
# 23                          Software Engineering Lead
# 24                 IT Technical Support - (Help Desk)
#
#                                              job_link  \
# 0   https://wuzzuf.net//jobs/p/aJ7j8e8h2MSI-Senior...
# 1   https://wuzzuf.net//jobs/p/RZUMQ4xVaZxq-Senior...
# 2   https://wuzzuf.net//jobs/p/dfVo2jjZ7Zgm-Machin...
# 3   https://wuzzuf.net//jobs/p/aFkYLkeugoKU-Senior...
# 4   https://wuzzuf.net//jobs/p/TBhJ0Eq7iimD-Produc...
# 5   https://wuzzuf.net//jobs/p/PmQv2opPhA7S-Data-S...
# 6   https://wuzzuf.net//jobs/p/6Y0UFr28bvE8-Senior...
# 7   https://wuzzuf.net//jobs/p/BLuBhHLGOsyD-AI-Tec...
# 8   https://wuzzuf.net//jobs/p/8MHaaeCAwJzU-Senior...
# 9   https://wuzzuf.net//jobs/p/demVdxTbTZL4-Senior...
# 10  https://wuzzuf.net//jobs/p/EVzEDYkzxJg2-Data-S...
# 11  https://wuzzuf.net//jobs/p/DZjts4Sd6UkF-Senior...
# 12  https://wuzzuf.net//jobs/p/jVAMAEFs9QN9-Python...
# 13  https://wuzzuf.net//jobs/p/5R0HaQ6Tn7oj-Senior...
# 14  https://wuzzuf.net//internship/CzzkNiyMyACu-In...
# 15  https://wuzzuf.net//jobs/p/VssduzQBDTOi-Data-S...
# 16  https://wuzzuf.net//jobs/p/hBvUbhBkorHH-Senior...
# 17  https://wuzzuf.net//jobs/p/dQBEtUvciP43-Data-M...
# 18  https://wuzzuf.net//jobs/p/7xgJnUKbVGL5-Produc...
# 19  https://wuzzuf.net//internship/woPTqpa9WDRl-Da...
# 20  https://wuzzuf.net//jobs/p/UOTTbSsxB9Q7-Senior...
# 21  https://wuzzuf.net//jobs/p/w9gACyzkbBpQ-Junior...
# 22  https://wuzzuf.net//jobs/p/PwaxCPLX03kC-Recept...
# 23  https://wuzzuf.net//jobs/p/VDVqGLDHK9fj-Softwa...
# 24  https://wuzzuf.net//jobs/p/uS9u4FCwHKzk-IT-Tec...
#
#                   job_loaction                 job_type
# 0     New Cairo, Cairo, Egypt                 Full Time
# 1     New Cairo, Cairo, Egypt   Full TimeWork From Home
# 2                Cairo, Egypt                 Full Time
# 3                Cairo, Egypt   Full TimeWork From Home
# 4   Ameria, Alexandria, Egypt                 Part Time
# 5     New Cairo, Cairo, Egypt                 Full Time
# 6         Maadi, Cairo, Egypt                 Full Time
# 7         Maadi, Cairo, Egypt                 Full Time
# 8     New Nozha, Cairo, Egypt                 Full Time
# 9     New Cairo, Cairo, Egypt   Full TimeWork From Home
# 10                Giza, Egypt                 Full Time
# 11               Cairo, Egypt            Work From Home
# 12         Dokki, Giza, Egypt                 Full Time
# 13   Obour City, Cairo, Egypt                 Full Time
# 14  Ameria, Alexandria, Egypt                Internship
# 15  Sheikh Zayed, Giza, Egypt                 Full Time
# 16               Cairo, Egypt                 Full Time
# 17               Cairo, Egypt                 Full Time
# 18    Badr City, Cairo, Egypt                 Full Time
# 19               Cairo, Egypt                Internship
# 20         Dokki, Giza, Egypt                 Full Time
# 21         Dokki, Giza, Egypt                 Full Time
# 22    New Cairo, Cairo, Egypt                 Full Time
# 23               Cairo, Egypt                 Full Time
# 24   Hurghada, Red Sea, Egypt                 Full Time

# %%
lst_of_job_title = input().split(',')
df_all = pd.DataFrame()
for job in lst_of_job_title:
  df = scrape_pages(job)
  df_all = pd.concat([df_all, df], axis = 0)
df_all.to_csv('job', index = False)
# Out:
# data analysis,data science,machine learning,business intelligence
